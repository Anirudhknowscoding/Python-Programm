# %%
# 1. Creating different data structures for students

students_list = ["ANIRUDH", "YABI", "AAYUSH"]

students_tuple = ("ANIRUDH", "YABI", "AAYUSH")

students_dict = {
    101: "ANIRUDH",
    102: "YABI",
    103: "AAYUSH"
}

print("--- Initial Data Structures")
print(f"List:       {students_list}")
print(f"Tuple:      {students_tuple}")
print(f"Dictionary: {students_dict}\n")


# 2. Performing Dictionary Operations

# --- OPERATION 1: ADD ---
students_dict[104] = "Harry"
print("--- After Adding Roll 104 (Harry) ---")
print(f"Dictionary: {students_dict}\n")


# --- OPERATION 2: UPDATE ---
students_dict[102] = "John"
print("--- After Updating Roll 102 to 'John' ---")
print(f"Dictionary: {students_dict}\n")


# --- OPERATION 3: DELETE ---
if 103 in students_dict:
    del students_dict[103]
print("--- After Deleting Roll 103 ---")
print(f"Dictionary: {students_dict}\n")


# Final State summary
print("--- Final State of All Structures ---")
print(f"List (Unchanged):       {students_list}")
print(f"Tuple (Immutable):      {students_tuple}")
print(f"Dictionary (Modified):  {students_dict}")
# Out:
# --- Initial Data Structures
# List:       ['ANIRUDH', 'YABI', 'AAYUSH']
# Tuple:      ('ANIRUDH', 'YABI', 'AAYUSH')
# Dictionary: {101: 'ANIRUDH', 102: 'YABI', 103: 'AAYUSH'}
#
# --- After Adding Roll 104 (Harry) ---
# Dictionary: {101: 'ANIRUDH', 102: 'YABI', 103: 'AAYUSH', 104: 'Harry'}
#
# --- After Updating Roll 102 to 'John' ---
# Dictionary: {101: 'ANIRUDH', 102: 'John', 103: 'AAYUSH', 104: 'Harry'}
#
# --- After Deleting Roll 103 ---
# Dictionary: {101: 'ANIRUDH', 102: 'John', 104: 'Harry'}
#
# --- Final State of All Structures ---
# List (Unchanged):       ['ANIRUDH', 'YABI', 'AAYUSH']
# Tuple (Immutable):      ('ANIRUDH', 'YABI', 'AAYUSH')
# Dictionary (Modified):  {101: 'ANIRUDH', 102: 'John', 104: 'Harry'}
